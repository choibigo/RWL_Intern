# %% [markdown]
# 04-4 프로그램의 입출력

# %% [markdown]
# sys 모듈 사용하기

# %%
# sys1.py
import sys

args = sys.argv[1:]
for i in args:
    print(i)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#sys2.py
import sys

sum = 0
args = sys.argv[1:]
for i in args:
    sum = sum + int(i)

prin (sum)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# sys3.py
import sys
args = sys.argv[1:]
for i in args:
    print(i.upper(), end=' ')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def up(*args):
    for i in args:
        print(i.upper(), end = ' ')

up("hello","world","jocoding")
# Out:
# HELLO WORLD JOCODING
