# %% [markdown]
# 05-2 모듈

# %% [markdown]
# 모듈 만들기

# %%
import mod1
print(mod1.add(3,4))
# Out:
# 7

# %%
from mod1 import add # mod1 에서 add 라는 함수를 가져왔기 때문에 바로 쓸 수 있다.
# print(mod1.add(3,4))
print(add(3,4))
print(sub(3,4))
# Out:
# 7
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       2 # print(mod1.add(3,4))
#       3 print(add(3,4))
# ----> 4 print(sub(3,4))
#
# NameError: name 'sub' is not defined

# %%
from mod1 import add, sub 
print(add(3,4))
print(sub(3,4))
# Out:
# 7
# -1

# %% [markdown]
# if __name__ == "__main__":의 의미

# %%
import mod1

# %% [markdown]
# 클래스나 변수 등을 포함한 모듈

# %%
import mod2
print(mod2.PI)

a = mod2.Math()
print(a.solv(2))
# Out:
# 3.141592
# 12.566368

# %% [markdown]
# 다른 디렉토리에 있는 모듈을 불러오는 방법
