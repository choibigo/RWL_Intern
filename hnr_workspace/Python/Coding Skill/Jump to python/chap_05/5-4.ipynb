# %% [markdown]
# 05-4 예외처리

# %%
f = open("나없는파일", 'r')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 f = open("나없는파일", 'r')
#
# File c:\Users\hhnur\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '나없는파일'

# %%
4 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 4 / 0
#
# ZeroDivisionError: division by zero

# %%
a = [1, 2, 3]
a[3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 a = [1, 2, 3]
# ----> 2 a[3]
#
# IndexError: list index out of range

# %% [markdown]
# 오류 예외 처리 기법

# %%
try :
    #오류가 발생할 수 있는 구문
except Exception as e:
    # 오류 발생
else:
    # 오류 발생하지 않음
finally:
    # 무조건 마지막에 실행

# %% [markdown]
# try-except 문

# %%
try:
    4 / 0
except ZeroDivisionError as e:
# 위처럼 4를 0으로 나누려고 하면 ZeroDivisionError가 발생하여 except 블록이 실행되고, 오류 변수 e에 담긴 오류 메시지를 출력할 수 있다.
    print(e)
# Out:
# division by zero

# %% [markdown]
# try-finally 문

# %%
try:
    f = open('foo.txt', 'w')
    # 무언가를 수행한다.

    (... 생략 ...)

finally:
    f.close()  # 중간에 오류가 발생하더라도 무조건 실행된다.

# %% [markdown]
# 여러 개의 오류 처리하기

# %%
try:
    a = [1,2]
    print(a[3])
    4/0
except ZeroDivisionError:
    print("0으로 나눌 수 없습니다.")
except IndexError:
    print("인덱싱 할 수 없습니다.")
# Out:
# 인덱싱 할 수 없습니다.

# %%
try:
    a = [1,2]
    print(a[3])
    4/0
except ZeroDivisionError as e:
    print(e)
except IndexError as e:
    print(e)
# Out:
# list index out of range

# %%
try:
    # a = [1,2]
    # print(a[3])
    4/0
except (ZeroDivisionError, IndexError) as e:
    print(e)
# Out:
# division by zero

# %% [markdown]
# try-else 문

# %%
try:
    age=int(input('나이를 입력하세요: '))
except:
    print('입력이 정확하지 않습니다.')
else:
    if age <= 18:
        print('미성년자는 출입금지입니다.')
    else:
        print('환영합니다.')
# Out:
# 환영합니다.

# %% [markdown]
# 오류 회피하기

# %%
try:
    f = open("나 없는 파일",'r')
except FileNotFoundError:
    pass
print("안녕")
# Out:
# 안녕

# %% [markdown]
# 오류 일부러 발생시키기

# %%
class Bird:
    def fly(self):
        raise NotImplementedError

class Eagle(Bird):
    pass

eagle = Eagle()
eagle.fly()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[16], line 8
#       6     pass
#       7 eagle = Eagle()
# ----> 8 eagle.fly()
#
# Cell In[16], line 3, in Bird.fly(self)
#       2 def fly(self):
# ----> 3     raise NotImplementedError
#
# NotImplementedError:

# %% [markdown]
# 예외 만들기

# %%
class MyError(Exception):
    pass

# %%
def say_nick(nick):
    if nick == '바보':
        raise MyError()
    print(nick)

say_nick("바보")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 6
#       3         raise MyError()
#       4     print(nick)
# ----> 6 say_nick("바보")
#
# Cell In[17], line 3, in say_nick(nick)
#       1 def say_nick(nick):
#       2     if nick == '바보':
# ----> 3         raise MyError()
#       4     print(nick)
#
# NameError: name 'MyError' is not defined

# %%
try:
    say_nick("천사")
    say_nick("바보")

except MyError as e:
    print(e)
# Out:
# 천사
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       2     say_nick("천사")
# ----> 3     say_nick("바보")
#       5 except MyError as e:
#
# Cell In[17], line 3, in say_nick(nick)
#       2 if nick == '바보':
# ----> 3     raise MyError()
#       4 print(nick)
#
# NameError: name 'MyError' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 5
#       2     say_nick("천사")
#       3     say_nick("바보")
# ----> 5 except MyError as e:
#       6     print(e)
#
# NameError: name 'MyError' is not defined

# %%
class MyError(Exception):
    def __str__(self):
        return "허용되지 않는 별명입니다."

def say_nick(nick):
    if nick == '바보':
        raise MyError()
    print(nick)

try:
    say_nick("천사")
    say_nick("바보")
except MyError as e:
    print(e)
# Out:
# 천사
# 허용되지 않는 별명입니다.
