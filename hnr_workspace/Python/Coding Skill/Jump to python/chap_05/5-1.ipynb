# %% [markdown]
# 05-1 클래스

# %%
# calculator.py
result = 0

def add(num):
    global result
    result += num  # 결괏값(result)에 입력값(num) 더하기
    return result  # 결괏값 리턴

print(add(3))
print(add(4))
# Out:
# 3
# 7

# %% [markdown]
# - 만약 계산기가 100개 혹은 1000개라면?

# %%
# calculator2.py
result1 = 0
result2 = 0

def add1(num):  # 계산기1
    global result1
    result1 += num
    return result1

def add2(num):  # 계산기2
    global result2
    result2 += num
    return result2

print(add1(3))
print(add1(4))
print(add2(3))
print(add2(7))
# Out:
# 3
# 7
# 3
# 10

# %%
 # calculator3.py
class Calculator:
    def __init__(self):
        self.result = 0

    def add(self, num):
        self.result += num
        return self.result

cal1 = Calculator()
cal2 = Calculator()

print(cal1.add(3))
print(cal1.add(4))
print(cal2.add(3))
print(cal2.add(7))
# Out:
# 3
# 7
# 3
# 10

# %%
class Calculator:
    def __init__(self):
        self.result = 0

    def add(self, num):
        self.result += num
        return self.result

    def sub(self, num):
        self.result -= num
        return self.result

# %% [markdown]
# 클래스와 객체

# %%
class Cookie:
    pass

초코쿠기 = Cookie() # return 값으로 인스턴스가 나옴
아몬드쿠키 = Cookie()

# %% [markdown]
# 클래스를 어떻게 만들지 먼저 구상하기

# %% [markdown]
# - 클래스는 결국 변수와 함수에 대한 설계도이다.

# %%
class FourCal:
    pass

a = FourCal() 
print(type(a)) # FourCal 이라는 Class 로 만든 객체가 담기게 된다.
# Out:
# <class '__main__.FourCal'>

# %%
class FourCal:
    def setdata(self, first, second): # 내부 함수는 메서드라고 표현한다.
        self.first = first
        self.second = second

    def add(self, num):
        self.result += num
        return self.result

a = FourCal() # a 는 객체(인스턴스)
b = FourCal()

a.setdata(4,2) # a -> self, 4 -> first, 2 -> second
b.setdata(4,2)
a.add
print(a.first)
print(a.second)

print(b.first)
print(b.second)
# Out:
# 4
# 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class FourCal:
    def setdata(self, first, second): # 내부 함수는 메서드라고 표현한다.
        self.first = first
        self.second = second

    def add(self):
        result = self.first + self.second # a.first = 4, a.second = 2
        return result

a = FourCal() # a 는 객체(인스턴스)

a.setdata(4,2) # a -> self, 4 -> first, 2 -> second

print(a.add())
# Out:
# 6

# %% [markdown]
# 곱하기, 빼기, 나누기 기능 만들기

# %%
class FourCal:
    def setdata(self, first, second):
        self.first = first
        self.second = second

    def add(self):
        result = self.first + self.second
        return result
    
    def mul(self):
        result = self.first * self.second
        return result
    
    def sub(self):
        result = self.first - self.second
        return result
    
    def div(self):
        result = self.first / self.second
        return result

a = FourCal()
a.setdata(4,2)

print(a.add())
print(a.mul())
print(a.sub())
print(a.div())
# Out:
# 6
# 8
# 2
# 2.0

# %% [markdown]
# b 라는 완전히 별도의 계산기를 만들어서 처리를 할 수도 있다.

# %%
class FourCal:
    def setdata(self, first, second):
        self.first = first
        self.second = second

    def add(self):
        result = self.first + self.second
        return result
    
    def mul(self):
        result = self.first * self.second
        return result
    
    def sub(self):
        result = self.first - self.second
        return result
    
    def div(self):
        result = self.first / self.second
        return result

a = FourCal()
a.setdata(4,2)

print(a.add())
print(a.mul())
print(a.sub())
print(a.div())

b = FourCal()
b.setdata(10,5)
print(b.add())
print(b.mul())
print(b.sub())
print(b.div())
# Out:
# 6
# 8
# 2
# 2.0
# 15
# 50
# 5
# 2.0

# %% [markdown]
# 생성자

# %%
class FourCal:
    def setdata(self, first, second):
        self.first = first
        self.second = second

    def add(self):
        result = self.first + self.second
        return result
    
    def mul(self):
        result = self.first * self.second
        return result
    
    def sub(self):
        result = self.first - self.second
        return result
    
    def div(self):
        result = self.first / self.second
        return result

a = FourCal() # setdata 에서 a.first 랑 b.first 저장해주는 과정이 없음 -> setdata 라는게 무조건 먼저 있어야지 작동
a.add()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 23
#      20         return result
#      22 a = FourCal()
# ---> 23 a.add()
#
# Cell In[7], line 7, in FourCal.add(self)
#       6 def add(self):
# ----> 7     result = self.first + self.second
#       8     return result
#
# AttributeError: 'FourCal' object has no attribute 'first'

# %% [markdown]
# - 클래스로부터 인스턴스를 찍어낼 때 무조건 처음에 실행되는 것을 생성자라고 한다

# %%
class FourCal:
    def __init__(self, first, second): # 생성자는 무조건 1빠로 실행 
        self.first = first
        self.second = second

    def setdata(self, first, second):
        self.first = first
        self.second = second

    def add(self):
        result = self.first + self.second
        return result
    
    def mul(self):
        result = self.first * self.second
        return result
    
    def sub(self):
        result = self.first - self.second
        return result
    
    def div(self):
        result = self.first / self.second
        return result

a = FourCal() # Class 로부터 인스턴스를 찍어낼때 __init__ 의 조건을 충족하지 못하면 아예 찍어내기 자체를 하지 못함
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 26
#      23         result = self.first / self.second
#      24         return result
# ---> 26 a = FourCal()
#
# TypeError: FourCal.__init__() missing 2 required positional arguments: 'first' and 'second'

# %%
class FourCal:
    def __init__(self, first, second): # 생성자는 무조건 1빠로 실행 
        self.first = first
        self.second = second

    def setdata(self, first, second):
        self.first = first
        self.second = second

    def add(self):
        result = self.first + self.second
        return result
    
    def mul(self):
        result = self.first * self.second
        return result
    
    def sub(self):
        result = self.first - self.second
        return result
    
    def div(self):
        result = self.first / self.second
        return result

a = FourCal(4,2)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 클래스의 상속

# %%
class 클래스_이름(상속할_클래스_이름)

# %%
class FourCal:
    def __init__(self, first, second): # 생성자는 무조건 1빠로 실행 
        self.first = first
        self.second = second

    def setdata(self, first, second):
        self.first = first
        self.second = second

    def add(self):
        result = self.first + self.second
        return result
    
    def mul(self):
        result = self.first * self.second
        return result
    
    def sub(self):
        result = self.first - self.second
        return result
    
    def div(self):
        result = self.first / self.second
        return result

class MoreFourCal(FourCal): 
    pass

a = MoreFourCal(4,2)
print(a.add())
print(a.mul())
print(a.sub())
print(a.div())
# Out:
# 6
# 8
# 2
# 2.0

# %%
class FourCal:
    def __init__(self, first, second): # 생성자는 무조건 1빠로 실행 
        self.first = first
        self.second = second

    def setdata(self, first, second):
        self.first = first
        self.second = second

    def add(self):
        result = self.first + self.second
        return result
    
    def mul(self):
        result = self.first * self.second
        return result
    
    def sub(self):
        result = self.first - self.second
        return result
    
    def div(self):
        result = self.first / self.second
        return result

class MoreFourCal(FourCal): 
    def pow(self): # 자식한테만 추가
        result = self.first ** self.second
        return result

a = MoreFourCal(4,2)
print(a.add())
print(a.pow())
# Out:
# 6
# 16

# %% [markdown]
# 메서드 오버라이딩 : 부모랑 자식이랑 싸우면 자식이 이긴다

# %%
class FourCal:
    def __init__(self, first, second): # 생성자는 무조건 1빠로 실행 
        self.first = first
        self.second = second

    def setdata(self, first, second):
        self.first = first
        self.second = second

    def add(self):
        result = self.first + self.second
        return result
    
    def mul(self):
        result = self.first * self.second
        return result
    
    def sub(self):
        result = self.first - self.second
        return result
    
    def div(self):
        result = self.first / self.second
        return result

class MoreFourCal(FourCal): 
    def pow(self): # 자식한테만 추가
        result = self.first ** self.second
        return result

a = MoreFourCal(4,0)
a.div()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 32
#      29         return result
#      31 a = MoreFourCal(4,0)
# ---> 32 a.div()
#
# Cell In[1], line 23, in FourCal.div(self)
#      22 def div(self):
# ---> 23     result = self.first / self.second
#      24     return result
#
# ZeroDivisionError: division by zero

# %%
class FourCal:
    def __init__(self, first, second): # 생성자는 무조건 1빠로 실행 
        self.first = first
        self.second = second

    def setdata(self, first, second):
        self.first = first
        self.second = second

    def add(self):
        result = self.first + self.second
        return result
    
    def mul(self):
        result = self.first * self.second
        return result
    
    def sub(self):
        result = self.first - self.second
        return result
    
    def div(self):
        result = self.first / self.second
        return result

class SafeFourCal(FourCal): 
    def div(self): # 자식한테만 추가
        if self.second == 0:
            return 0
        else:
            return self.first / self.second

a = SafeFourCal(4,0)
a.div() # 자기의 div 를 사용
# Out:
# 0

# %% [markdown]
# 클래스변수

# %%
class Family:
    lastname = "김"
    
# 김씨 family 의 성은 모두 김씨이다.
a = Family()
b = Family()

a.lastname = "박"

print(a.lastname)
print(b.lastname)
# Out:
# 박
# 김
