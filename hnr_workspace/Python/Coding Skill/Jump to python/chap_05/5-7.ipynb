# %% [markdown]
# 05-7 외부 라이브러리

# %%
from faker import Faker
fake = Faker()

print(fake.name())

print(fake.address())

print(fake.text())
# Out:
# Angela Ryan
# 7421 Chelsea Extensions Suite 244
# Johnsonbury, AR 03397
# Sing player federal town they. Left strong debate fire gun.
# Note appear myself start magazine side network. Beautiful fill couple local help. End side player move.

# %%
from faker import Faker
fake = Faker('ko-KR')

print(fake.name())

print(fake.address())

print(fake.text())
# Out:
# 박서영
# 충청남도 예산군 서초중앙7길 473 (광수한읍)
# Laboriosam mollitia adipisci placeat commodi aperiam possimus. Fugiat nemo unde magni iste enim. Omnis accusantium impedit magnam aut eum.
