# %% [markdown]
# - [ ] ResNet <- 이 사람들은 무엇을 해결하려고 했는가? degrading problem? (논문 참고할 것)
#   - [ ] 그리고 ResNet 읽고 직접 구현할 것.
#   - [ ] 파이토치로 데이터로더, 즉 데이터셋을 직접 만들어봐야함.
#     - [ ] init, get item, len을 사용할 것.
