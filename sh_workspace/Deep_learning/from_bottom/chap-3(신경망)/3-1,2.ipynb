# %% [markdown]
# ### chap3. 신경망
# ###### 신경망은 퍼셉트론의 가중치를 데이터로부터 스스로 학습하도록 확장한 모델
#
# ----

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ##### 신경망은 ***입력층***,***은닉층***,***출력층***으로 구성된다.

# %% [markdown]
# ![image.png](attachment:image.png)
# - h(x)는 ***활성화 함수***로 입력 신호의 총합을 출력 신호로 변환하는 함수다.

# %% [markdown]
# ![image.png](attachment:image.png)
# - 활성화 함수의 처리 과정
# ---

# %% [markdown]
# ### 3-2. 활성화 함수

# %% [markdown]
# 1. 계단 함수
#
# ![image.png](attachment:image.png)
#
#
# 2. 시그모이드 함수
#
# ![image-2.png](attachment:image-2.png)
#
# ##### *퍼셉트론과 신경망의 주된 차이는 활성화 함수이다.

# %%
# 계단 함수 구현
import numpy as np

def step_function(x): # 입력을 실수만 받음
    if x > 0:
        return 1
    else:
        return 0

def step_function(x): # 입력을 리스트로도 받을 수 있게 함
    y = x > 0
    return y.astype(np.int) # 리스트에서 bool타입을 int로 바꾼다

# %%
# 계단 함수 그리기
import numpy as np
import matplotlib.pylab as plt

def step_function(x): # 입력을 리스트로도 받을 수 있게 함
    y = x > 0
    return y.astype(int) 

x = np.arange(-5.0, 5.0, 0.1)
y = step_function(x)
plt.plot(x,y)
plt.ylim(-0.1, 1.1) # y축의 범위 지정
plt.show()

# %%
# sigmoid 함수 그리기
import numpy as np
import matplotlib.pylab as plt

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

x = np.arange(-5.0, 5.0, 0.1)
y = sigmoid(x)
plt.plot(x, y)
plt.ylim(-0.1, 1.1)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np
import matplotlib.pylab as plt

def step_function(x): # 입력을 리스트로도 받을 수 있게 함
    y = x > 0
    return y.astype(int) 

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

x = np.arange(-5.0, 5.0, 0.1)
y1 = step_function(x)
y2 = sigmoid(x)

plt.plot(x,y1, label = 'step_function')
plt.plot(x,y2,linestyle = '--', label = 'sigmoid_function')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()

# %% [markdown]
# - 두 함수의 차이점: 매끈함
# - 두 함수의 공통점: 둘 다 비선형 함수이다.
# - 신경망에서는 비선형 함수만을 사용해야 한다.(아니면 여러 층으로 구성하는 이점을 살릴 수 없기 때문이다.)

# %% [markdown]
# 3. ReLU 함수
#
# ![image-2.png](attachment:image-2.png)

# %%
# ReLU 함수 그리기
import numpy as np
import matplotlib.pylab as plt

def relu(x):
    return np.maximum(0,x)

x = np.arange(-5.0, 5.0, 0.1)
y = relu(x)

plt.plot(x,y)
plt.show()
