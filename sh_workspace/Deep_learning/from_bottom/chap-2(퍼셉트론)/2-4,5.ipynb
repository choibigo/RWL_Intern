# %% [markdown]
# ### 2-4. 퍼센트론의 한계
#
# ---

# %% [markdown]
# ##### XOR 게이트란 x1과 x2 중 한쪽이 1일 때만 1을 출력한다.
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - 지금까지 본 퍼셉트론으로는 XOR 게이트를 구현할 수 없다.
#
#
# ![image.png](attachment:image.png)
# - OR 게이트는 0과 1을 함수로 그렸을 때 선 하나가 나눌 수 있지만 XOR은 선 하나로 나눌 수가 없다.
#
# ![image-2.png](attachment:image-2.png)
# - XOR 그래프
#
# ![image-3.png](attachment:image-3.png)
# - 곡선으로만 XOR을 나눌 수 있다.(비선형 영역)
# ##### 즉 퍼셉트론으로는 XOR 게이트를 표현할 수 없다.
# ---

# %% [markdown]
# #### XOR을 표현하기 위해서는 ***다층 퍼셉트론***을 만들어 보자.(기존의 게이트들을 조합)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
# - AND,NAND,OR 게이튿을 조합해서 XOR게이트를 만들 수 있다.

# %%
import numpy as np

def AND(x1,x2):
    x = np.array([x1, x2])
    w = np.array([0.5, 0.5])
    b = -0.7
    tmp = np.sum(x*w) + b
    if tmp > 0:
        return 1
    if tmp <= 0:
        return 0

def NAND(x1,x2):
    x = np.array([x1, x2])
    w = np.array([-0.5, -0.5])
    b = 0.7
    tmp = np.sum(x*w) + b
    if tmp > 0:
        return 1
    if tmp <= 0:
        return 0


def OR(x1,x2):
    x = np.array([x1, x2])
    w = np.array([0.5, 0.5])
    b = -0.2
    tmp = np.sum(x*w) + b
    if tmp > 0:
        return 1
    if tmp <= 0:
        return 0

def XOR(x1,x2):
    s1 = NAND(x1, x2)
    s2 = OR(x1, x2)
    y = AND(s1, s2)
    return y

print(XOR(0,0))
print(XOR(0,1))
print(XOR(1,0))    
print(XOR(1,1))
# Out:
# 0
# 1
# 1
# 0

# %% [markdown]
# ![image.png](attachment:image.png)
#
# - 위의 그림과 같이 왼쪽부터 차례로 0,1,2층이라고 하고 AND,OR,NAND는 단층 퍼셉트론, XOR과 같이 여러 층을 갖고 있으면 다층 퍼셉트론이라고 한다.
# ----

# %% [markdown]
# ### 정리
# - 퍼셉트론은 입출력을 갖춘 알고리즘이다. 입력을 주면 정해진 규칙에 따른 값을 출력한다.(임계값을 넘으면 1,아니면 0 출력)
#
# - 퍼셉트론으로 AND,OR 게이트 등의 논리 회로를 표현할 수 있다.
# - XOR 게이트(다층 퍼셉트론)는 단층 퍼셉트론으로는 표현할 수 없다.
