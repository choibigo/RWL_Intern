# %% [markdown]
# ### chap-7. 합성곱 신경망(CNN)
#
# ![image.png](attachment:image.png)
#
# - 이전까지는 인접하는 계층의 모든 뉴런과 결합되어 있는 완전 연결이었다.
#
#
# ![image-2.png](attachment:image-2.png)
#
# - CNN은 합성곱 계층(Conv)과 풀링 계층(Pooling)이 추가되어 Conv-ReLU-Pooling 흐름으로 연결된다. 하지만 출력에 가까운 층에서는 기존 층과 같이 구성할 수 있다.
#
# - 완전연결 계층은 *데이터의 형상이 무시* 되기 때문에 이미지와 같이 3차원 데이터인 경우 3차원 데이터를 제대로 이해하지 못한다.
# - 반면 합성곱 계층은 형상을 유지하기 때문에 3차원 데이터를 제대로 이해할 수 있다.
# ----

# %% [markdown]
# #### 합성곱 연산
#
# ![image.png](attachment:image.png)
#
# - 입력: (4*4), 필터(커널): (3*3), 출력: (2*2)
#
#
# ![image-2.png](attachment:image-2.png)
#
# - CNN에도 매개변수가 존재한다. 필터가 '가중치'에 해당한다.
#
#
# ---

# %% [markdown]
# #### 패딩
#
# ###### 패딩: 합성곱 연산을 수행하기 전에 입력 데이터 주변을 특정 값으로 채운다. (폭이 1뿐만 아니라 2,3이 될 수도 있다.)
#
# ![image.png](attachment:image.png)
#
# ----

# %% [markdown]
# #### 스트라이드
# ###### 스트라이드: 스트라이드 크기에 따라 필터를 적용하는 윈도우가 슬라이드 하는 크기가 달라진다.
#
# ![image.png](attachment:image.png)
#
# ----

# %% [markdown]
# #### 3차원 데이터의 합성곱 연산
#
# ![image.png](attachment:image.png)
#
# - (입력1*필터1) + (입력2*필터2) + (입력3*필터3)을 계산하면 된다.
# - *입력 데이터의 채널 수와 필터의 채널 수가 같아야 한다.
# ---

# %% [markdown]
# #### 배치 처리
# ![image.png](attachment:image.png)
#
# - 실전에서는 합성곱 연산도 배치 처리를 하는데 각 계층은 이를 한 차원 늘린 4차원으로 보고 한 번에 4차원 계산을 진행한다.(데이터 수, 채널 수, 높이, 너비), 데이터가 N개일 때 위와 같다.

# %%
#240
