# %% [markdown]
# # 4-4. 프로그램의 입출력

# %% [markdown]
# ###### 명령어를 이용하여 인수를 전달하는 방법

# %%
# 명령어 끝에 인수들을 입력하면 인수로 들어감.
import sys

args = sys.argv[0:]
for i in args:
    print(i)

# %% [markdown]
# - python ~~.py [argument] [argument] ...
