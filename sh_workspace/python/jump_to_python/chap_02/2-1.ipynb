# %% [markdown]
# ## 2-1. 숫자형

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = 123
print(type(a))
# Out:
# <class 'int'>

# %%
a = 4.24E10
b = 4.24e-10

print(a)
print(b)
# Out:
# 42400000000.0
# 4.24e-10

# %% [markdown]
# E는 *10^10를 의미하고 e^-10은 *10^-10을 의미한다.

# %%
a = 3
b = 4
print(a + b)
print(a - b)
print(a*b)
print(a/b)
print(a**b)
print(b%a)
print(b//a)
# Out:
# 7
# -1
# 12
# 0.75
# 81
# 1
# 1

# %%
a = 3
a += 1

b = 5
b *= 2

print(a)
print(b)
# Out:
# 4
# 10
