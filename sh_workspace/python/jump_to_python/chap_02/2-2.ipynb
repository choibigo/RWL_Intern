# %% [markdown]
# ## 2-2. 문자열 자료형

# %%
a = "Life is too short, You need Python"
b = "a"
c = "123"
print(type(a))
# Out:
# <class 'str'>

# %%
a = "hello world"
b = 'Python is fun'
c = """Life is too short, You need Python"""
d = '''Life is too short, You need Python'''
print(a)
print(b)
print(c)
print(d)
# Out:
# hello world
# Python is fun
# Life is too short, You need Python
# Life is too short, You need Python

# %%
# 문자열에 작은따옴표 포함하기
a = "Python's favorite food is perl"
b = 'Python\'s favorite food is perl' # \는 따옴표를 ""안에 있는 걸로 보게 해준다.
print(a)
print(b)
# Out:
# Python's favorite food is perl
# Python's favorite food is perl

# %%
a = "Life is \n too short" # \n은 줄바꿈을 의미한다.
print(a)

b = "Life is \t too short" # \t는 tab을 의미한다.
print(b)
# Out:
# Life is
#  too short
# Life is 	 too short

# %% [markdown]
# ## 문자열 연산하기

# %%
head = "Python"
tail = " is fun!"
print(head + tail)
# Out:
# Python is fun!

# %%
a = "python"
print(a * 3)
# Out:
# pythonpythonpython

# %%
print("=" * 50)
print("My Program")
print("=" * 50)
# Out:
# ...
# My Program
# ...

# %%
a = "Life is too short, You need Python"
print(a[0])
print(a[12])
print(a[-2]) # -는 맨 끝에서부터 뒤로 온다.
# Out:
# L
# s
# o

# %% [markdown]
# - 문자열 index는 0부터 시작

# %%
a = "Life is too short, You need Python"
b = a[::-2]
print(b)
# Out:
# nhy enuY,rh o iei

# %% [markdown]
# - 슬라이싱: a[2:9:2] 인덱스 2번째 이상부터 9번째 미만까지 2칸 간격으로!
# - 빈칸으로 둘 수도 있다.

# %%
a = "Life is too short, You neet Python"
b = a[3::3]
c = a[:13]
print(b)
print(c)
# Out:
# esosr ue tn
# Life is too s

# %% [markdown]
# ## 문자열 포매팅

# %% [markdown]
# ###### 문자열 포매팅: 문자열 안에 어떤 값을 삽입하는 방법

# %%
a = "I eat %d apples." % 3 # %d는 정수값을 의미한다.
print(a)
# Out:
# I eat 3 apples.

# %%
b = "I eat %s apples." %"five" # %s는 문자열을 의미한다.
print(b)
# Out:
# I eat five apples.

# %%
number = 3
a = "I eat %d apples" %number
print(a)
# Out:
# I eat 3 apples

# %%
# 2개 이상의 값을 넣을 수도 있다.
number = 10
day = "three"
a = "I ate %d apples. so I was sick for %s days." %(number, day)
print(a)
# Out:
# I ate 10 apples. so I was sick for three days.

# %%
# %s는 모두 입력으로 쓸 수 있다.
a = "I have %s apples" %3
print(a)

b = "rete is %s" %3.234
print(b)

# %를 쓰고 싶다면 %%로 두 개를 입력하면 된다.
c = "Error is %d%%." %98
print(c)
# Out:
# I have 3 apples
# rete is 3.234
# Error is 98%.

# %%
# 소수점 지정하기

a = "%.3f" %3.12342 #소수점 3자리까지 표현
print(a)
# Out:
# 3.123

# %%
# f를 이용해서 formating 할 수 있다.
name = "홍길동"
age =30
a = f'나의 이름은 {name}입니다. 나이는 {age+1}입니다.'
print(a)
# 37분 20초
# Out:
# 나의 이름은 홍길동입니다. 나이는 30입니다.

# %% [markdown]
# ## 문자열 관련 함수들

# %%
a = "hobby"
print(a.count('b'))
# Out:
# 2

# %%
a = " to the ".join('abcd')
print(a)
# Out:
# a to the b to the c to the d

# %%
a = "HI"
print(a.lower())
# Out:
# hi

# %%
a = " hi "
print(a.lstrip())
# Out:
# hi

# %%
a = "    hi    "
print(a.strip())
# Out:
# hi

# %%
a = "Life is too short"
print(a.replace("Life", "your leg"))
# Out:
# your leg is too short

# %%
a =  "Life is too short"
print(a.split())
# Out:
# ['Life', 'is', 'too', 'short']

# %%
a = "a:b:c:d"
print(a.split(':'))
# Out:
# ['a', 'b', 'c', 'd']
